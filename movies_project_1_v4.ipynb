# %% [markdown]
# ## Importing libraries

# %%
import time
import requests
from bs4 import BeautifulSoup as BS
import csv
import pandas as pd
import numpy as np
import json

# %%
#database connection
import sqlite3
import mysql.connector
import config
from mysql.connector import errorcode
from datetime import date, datetime, timedelta

# %%
#visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password
)
cursor = cnx.cursor(buffered=True)

# %%
api_key = config.api_key

# %% [markdown]
# ## Connecting to database

# %%
db_name = 'movie_database'

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
           "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)
try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)
cnx.commit()

# %% [markdown]
# Creating necessary tables

# %%
imdb_query = """CREATE TABLE imdb(
movie_id INT PRIMARY KEY AUTO_INCREMENT,
imdb_id TEXT NOT NULL,
name TEXT,
number_of_votes REAL,
user_rating REAL,
metascore_rating REAL,
gross TEXT
)"""

# %%
cursor.execute(imdb_query)
cnx.commit()

# %%
genre_movie = """CREATE TABLE genre_movie(
genre_id INT,
movie_id INT,
FOREIGN KEY (genre_id) REFERENCES genre(genre_id),
FOREIGN KEY (movie_id) REFERENCES imdb(movie_id))"""

# %%
cursor.execute(genre_movie)
cnx.commit()

# %%
genre_query = """CREATE TABLE genre_1(
imdb_id TEXT,
genre TEXT)"""

# %%
cursor.execute(genre_query)
cnx.commit()

# %%
stars_query = """CREATE TABLE stars(
star_id INT PRIMARY KEY AUTO_INCREMENT,
star_name TEXT)"""

# %%
cursor.execute(stars_query)
cnx.commit()

# %%
star_movie = """CREATE TABLE star_movie(
star_id INT,
movie_id INT,
FOREIGN KEY (star_id) REFERENCES stars(star_id),
FOREIGN KEY (movie_id) REFERENCES imdb(movie_id))"""

# %%
cursor.execute(star_movie)
cnx.commit()

# %%
tmdb_query = """CREATE TABLE tmdb(
tmdb_id TEXT NOT NULL,
title TEXT,
vote_count REAL,
vote_average REAL,
popularity REAL,
release_date DATETIME,
imdb_id TEXT)"""

# %%
cursor.execute(tmdb_query)
cnx.commit()

# %% [markdown]
# ## API calls and webscraping

# %% [markdown]
# Creating necessary functions for the IMDB webscraping

# %%
def imdb_call(start_number):
    url = f"https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&languages=en&sort=num_votes,desc&start={start_number}&explore=genres&ref_=adv_nxt"
    page = requests.get(url)
    soup = BS(page.content, 'html.parser')
    return soup

# %% [markdown]
# Creating dictionary of scraped data together with cleaning each row

# %%
def create_imdb_dict(soup):
    all_blocks = soup.find_all(class_='lister-item-content')
    imdb_id = [id['href'].split('/')[2] for id in soup.select('.lister-item-header a')]
    new_list = []
    for i in all_blocks:
        new_dict={}
        new_dict['imdb_id'] = i.select('.lister-item-header a')[0]['href'].split('/')[2]
        new_dict["name"] = i.select('.lister-item-header a')[0].text
        new_dict["num_of_votes"] = i.select('.sort-num_votes-visible')[0].text.split('\n')[2].replace(',','')
        try:
            cur_gross = i.select('.sort-num_votes-visible')[0].text.split('\n')[4]
            new_dict["gross"] = cur_gross
        except:
            new_dict["gross"] = None
        new_dict["user_rating"] = i.select('.inline-block.ratings-imdb-rating')[0].text.replace('\n', '')
        try:
            cur_meta = i.select('.inline-block.ratings-metascore')[0].text.split('\n')[1].strip()
            new_dict["metascore"] = cur_meta
        except:
            new_dict["metascore"] = None
        new_dict["genre"] = i.select('.genre')[0].text.replace('\n', '').strip().replace(' ','').split(',') 
        new_dict["movie_star"] = i.find(class_='ratings-bar').nextSibling.nextSibling.nextSibling.nextSibling.text.replace(', ','').strip().split('\n')[-4:]
        new_list.append(new_dict)
    return new_list, imdb_id

# %% [markdown]
# Creating tuple for inserting data to database

# %%
def create_imdb_tuple(imdb_dict_list):
    tuple_list = []
    for data in imdb_dict_list:
        new_tuple = (data['imdb_id'],data['name'], data['num_of_votes'], data['user_rating'],data['metascore'],data['gross'])
        tuple_list.append(new_tuple)
    return tuple_list

# %% [markdown]
# Inserting IMDB data to database

# %%
def insert_into_imdb(tuple_list):
    insert_imdb = """INSERT INTO imdb(imdb_id,name, number_of_votes, user_rating,metascore_rating, gross)
    VALUES (%s,%s,%s,%s,%s,%s)"""
    cursor.executemany(insert_imdb,tuple_list)
    cnx.commit()

# %% [markdown]
# Creating function for TMDB API call

# %%
def tmdb_call(imdb_id, api_key):
    tmdb_url= f'https://api.themoviedb.org/3/find/{imdb_id}?api_key={api_key}&&language=en-US&external_source=imdb_id'
    response = requests.get(tmdb_url)
    rsp=response.json()
    time.sleep(3)
    return rsp

# %%
def create_tmdb_dictionaries(rsp, imdb_id):
    tmdb_list= []
    tmdb_dict = {}
    for data in rsp["movie_results"]:
        tmdb_dict["tmdb_id"] = data["id"]
        tmdb_dict["tmdb_title"] = data["title"]
        tmdb_dict["tmdb_vote_count"] = data["vote_count"]
        tmdb_dict["tmdb_vote_avg"] = data["vote_average"]
        tmdb_dict["tmdb_popularity"] = data['popularity']
        tmdb_dict["release_date"] = data['release_date']
        tmdb_dict["imdb_id"] = imdb_id
        tmdb_list.append(tmdb_dict)
    return tmdb_list

# %%
def create_tmdb_tuple(tmdb_list):
    tuple_list_tmdb = []
    for data in tmdb_list:
        new_tuple_tmdb = (data['tmdb_id'],data['tmdb_title'], data['tmdb_vote_count'], data['tmdb_vote_avg'],data['tmdb_popularity'],data['release_date'],data['imdb_id'])
        tuple_list_tmdb.append(new_tuple_tmdb)
    return tuple_list_tmdb

# %%
def insert_into_tmdb(tuple_list_tmdb):
    insert_tmdb = """INSERT INTO tmdb(tmdb_id, title, vote_count, vote_average,popularity, release_date, imdb_id)
    VALUES (%s,%s,%s,%s,%s,%s,%s)"""
    cursor.executemany(insert_tmdb,tuple_list_tmdb)
    cnx.commit()

# %%
def id_genre_list(imdb_dict):
    id_genre_list = []
    for i in imdb_dict:
        id_genre_dict = {}
        id_genre_dict[i['imdb_id']]= i['genre']
        id_genre_list.append(id_genre_dict)
    return id_genre_list

# %%
def genre_formatting(id_genre_list):
    formatted_genres = []
    for genre in id_genre_list:
        for key, value in genre.items():
            for genre in value:
                genre_tuple = ( key ,genre )
                formatted_genres.append(genre_tuple)
    return formatted_genres

# %%
def insert_into_genre(genre_formatted):
    for elem in genre_formatted:
        insert_genre = """INSERT IGNORE INTO genre_1 (imdb_id, genre) VALUES (%s,%s)"""
        cursor.execute(insert_genre,elem)
        cnx.commit()

# %% [markdown]
# Function combining all steps in one call:
# 1. IMDB call
# 2. IMDB data insert to database
# 3. TMDB call
# 4. TMDB data inert to database

# %%
def all_results(start_number, api_key):
    cur = start_number
    results = []
    while cur < 3001:
        soup = imdb_call(cur)
        dict1 = create_imdb_dict(soup)
        imdb_tuple = create_imdb_tuple(dict1[0])
        results.append(dict1[0]) #use function to parse result, put in database and then move on to next call
        insert_into_imdb(imdb_tuple)
        genre_list = id_genre_list(dict1[0])
        genre_tuples = genre_formatting(genre_list)
        insert_into_genre(genre_tuples)
        for elem in dict1[1]:
            call = tmdb_call(elem, api_key)
            dict2 = create_tmdb_dictionaries(call, elem)
            tmdb_tuple = create_tmdb_tuple(dict2)
            insert_into_tmdb(tmdb_tuple)
        time.sleep(1) #Wait a second
        cur += 50
        print(f"insterting at {cur}")
    return results

# %% [markdown]
# Getting results

# %%
results = all_results(451,api_key)
# Out:
# insterting at 501
# insterting at 551
# insterting at 601
# insterting at 651
# insterting at 701
# insterting at 751
# insterting at 801
# insterting at 851
# insterting at 901
# insterting at 951
# insterting at 1001

# %%
results[1]
# Out:
# [{'imdb_id': 'tt0453467',
#   'name': 'Deja Vu',
#   'num_of_votes': '278901',
#   'gross': '$64.04M',
#   'user_rating': '7.0',
#   'metascore': '59',
#   'genre': ['Action', 'Crime', 'Sci-Fi'],
#   'movie_star': ['Denzel Washington',
#    'Paula Patton',
#    'Jim Caviezel',
#    'Val Kilmer']},
#  {'imdb_id': 'tt0163025',
#   'name': 'Jurassic Park III',
#   'num_of_votes': '278383',
#   'gross': '$181.17M',
#   'user_rating': '5.9',
#   'metascore': '42',
#   'genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'movie_star': ['Sam Neill',
#    'William H. Macy',
#    'Téa Leoni',
#    'Alessandro Nivola']},
#  {'imdb_id': 'tt0359950',
#   'name': 'The Secret Life of Walter Mitty',
#   'num_of_votes': '278159',
#   'gross': '$58.24M',
#   'user_rating': '7.3',
#   'metascore': '54',
#   'genre': ['Comedy', 'Drama', 'Fantasy'],
#   'movie_star': ['Ben Stiller', 'Kristen Wiig', 'Jon Daly', 'Kathryn Hahn']},
#  {'imdb_id': 'tt0129387',
#   'name': "There's Something About Mary",
#   'num_of_votes': '277292',
#   'gross': '$176.48M',
#   'user_rating': '7.1',
#   'metascore': '69',
#   'genre': ['Comedy', 'Romance'],
#   'movie_star': ['Cameron Diaz', 'Matt Dillon', 'Ben Stiller', 'Lee Evans']},
#  {'imdb_id': 'tt0110148',
#   'name': 'Interview with the Vampire: The Vampire Chronicles',
#   'num_of_votes': '277194',
#   'gross': '$105.26M',
#   'user_rating': '7.6',
#   'metascore': '59',
#   'genre': ['Drama', 'Horror'],
#   'movie_star': ['Brad Pitt',
#    'Tom Cruise',
#    'Antonio Banderas',
#    'Kirsten Dunst']},
#  {'imdb_id': 'tt0212720',
#   'name': 'A.I. Artificial Intelligence',
#   'num_of_votes': '277092',
#   'gross': '$78.62M',
#   'user_rating': '7.2',
#   'metascore': '65',
#   'genre': ['Drama', 'Sci-Fi'],
#   'movie_star': ['Haley Joel Osment',
#    'Jude Law',
#    "Frances O'Connor",
#    'Sam Robards']},
#  {'imdb_id': 'tt0120663',
#   'name': 'Eyes Wide Shut',
#   'num_of_votes': '276512',
#   'gross': '$55.69M',
#   'user_rating': '7.4',
#   'metascore': '68',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'movie_star': ['Tom Cruise',
#    'Nicole Kidman',
#    'Todd Field',
#    'Sydney Pollack']},
#  {'imdb_id': 'tt0053125',
#   'name': 'North by Northwest',
#   'num_of_votes': '276355',
#   'gross': '$13.28M',
#   'user_rating': '8.3',
#   'metascore': '98',
#   'genre': ['Adventure', 'Mystery', 'Thriller'],
#   'movie_star': ['Cary Grant',
#    'Eva Marie Saint',
#    'James Mason',
#    'Jessie Royce Landis']},
#  {'imdb_id': 'tt1041829',
#   'name': 'The Proposal',
#   'num_of_votes': '276254',
#   'gross': '$163.96M',
#   'user_rating': '6.7',
#   'metascore': '48',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'movie_star': ['Sandra Bullock',
#    'Ryan Reynolds',
#    'Mary Steenburgen',
#    'Craig T. Nelson']},
#  {'imdb_id': 'tt0056592',
#   'name': 'To Kill a Mockingbird',
#   'num_of_votes': '276142',
#   'gross': None,
#   'user_rating': '8.3',
#   'metascore': '88',
#   'genre': ['Crime', 'Drama'],
#   'movie_star': ['Gregory Peck',
#    'John Megna',
#    'Frank Overton',
#    'Rosemary Murphy']},
#  {'imdb_id': 'tt1397280',
#   'name': 'Taken 2',
#   'num_of_votes': '275817',
#   'gross': '$139.85M',
#   'user_rating': '6.2',
#   'metascore': '45',
#   'genre': ['Action', 'Thriller'],
#   'movie_star': ['Liam Neeson',
#    'Famke Janssen',
#    'Maggie Grace',
#    'Leland Orser']},
#  {'imdb_id': 'tt0449467',
#   'name': 'Babel',
#   'num_of_votes': '275606',
#   'gross': '$34.30M',
#   'user_rating': '7.4',
#   'metascore': '69',
#   'genre': ['Drama'],
#   'movie_star': ['Brad Pitt',
#    'Cate Blanchett',
#    'Gael García Bernal',
#    'Mohamed Akhzam']},
#  {'imdb_id': 'tt1037705',
#   'name': 'The Book of Eli',
#   'num_of_votes': '275482',
#   'gross': '$94.84M',
#   'user_rating': '6.9',
#   'metascore': '53',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'movie_star': ['Denzel Washington',
#    'Mila Kunis',
#    'Ray Stevenson',
#    'Gary Oldman']},
#  {'imdb_id': 'tt0113497',
#   'name': 'Jumanji',
#   'num_of_votes': '275323',
#   'gross': '$100.48M',
#   'user_rating': '7.0',
#   'metascore': '39',
#   'genre': ['Adventure', 'Comedy', 'Family'],
#   'movie_star': ['Robin Williams',
#    'Kirsten Dunst',
#    'Bonnie Hunt',
#    'Jonathan Hyde']},
#  {'imdb_id': 'tt1951261',
#   'name': 'The Hangover Part III',
#   'num_of_votes': '275004',
#   'gross': '$112.20M',
#   'user_rating': '5.8',
#   'metascore': '30',
#   'genre': ['Comedy', 'Crime'],
#   'movie_star': ['Bradley Cooper',
#    'Zach Galifianakis',
#    'Ed Helms',
#    'Justin Bartha']},
#  {'imdb_id': 'tt0489099',
#   'name': 'Jumper',
#   'num_of_votes': '274612',
#   'gross': '$80.17M',
#   'user_rating': '6.1',
#   'metascore': '35',
#   'genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'movie_star': ['Hayden Christensen',
#    'Samuel L. Jackson',
#    'Jamie Bell',
#    'Rachel Bilson']},
#  {'imdb_id': 'tt1517451',
#   'name': 'A Star Is Born',
#   'num_of_votes': '274096',
#   'gross': '$215.29M',
#   'user_rating': '7.7',
#   'metascore': '88',
#   'genre': ['Drama', 'Music', 'Romance'],
#   'movie_star': ['Lady Gaga',
#    'Bradley Cooper',
#    'Sam Elliott',
#    'Greg Grunberg']},
#  {'imdb_id': 'tt1245526',
#   'name': 'RED',
#   'num_of_votes': '274066',
#   'gross': '$90.38M',
#   'user_rating': '7.0',
#   'metascore': '60',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'movie_star': ['Bruce Willis',
#    'Helen Mirren',
#    'Morgan Freeman',
#    'Mary-Louise Parker']},
#  {'imdb_id': 'tt0147800',
#   'name': '10 Things I Hate About You',
#   'num_of_votes': '273869',
#   'gross': '$38.18M',
#   'user_rating': '7.3',
#   'metascore': '70',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'movie_star': ['Heath Ledger',
#    'Julia Stiles',
#    'Joseph Gordon-Levitt',
#    'Larisa Oleynik']},
#  {'imdb_id': 'tt0381849',
#   'name': '3:10 to Yuma',
#   'num_of_votes': '272645',
#   'gross': '$53.61M',
#   'user_rating': '7.7',
#   'metascore': '76',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'movie_star': ['Russell Crowe',
#    'Christian Bale',
#    'Ben Foster',
#    'Logan Lerman']},
#  {'imdb_id': 'tt0175880',
#   'name': 'Magnolia',
#   'num_of_votes': '272599',
#   'gross': '$22.46M',
#   'user_rating': '8.0',
#   'metascore': '77',
#   'genre': ['Drama'],
#   'movie_star': ['Tom Cruise',
#    'Jason Robards',
#    'Julianne Moore',
#    'Philip Seymour Hoffman']},
#  {'imdb_id': 'tt0379786',
#   'name': 'Serenity',
#   'num_of_votes': '272504',
#   'gross': '$25.51M',
#   'user_rating': '7.8',
#   'metascore': '74',
#   'genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'movie_star': ['Nathan Fillion',
#    'Gina Torres',
#    'Chiwetel Ejiofor',
#    'Alan Tudyk']},
#  {'imdb_id': 'tt0293662',
#   'name': 'The Transporter',
#   'num_of_votes': '272160',
#   'gross': '$25.30M',
#   'user_rating': '6.8',
#   'metascore': '51',
#   'genre': ['Action', 'Crime', 'Thriller'],
#   'movie_star': ['Jason Statham',
#    'Qi Shu',
#    'Matt Schulze',
#    'François Berléand']},
#  {'imdb_id': 'tt0107688',
#   'name': 'The Nightmare Before Christmas',
#   'num_of_votes': '271345',
#   'gross': '$75.08M',
#   'user_rating': '8.0',
#   'metascore': '82',
#   'genre': ['Animation', 'Family', 'Fantasy'],
#   'movie_star': ['Danny Elfman',
#    'Chris Sarandon',
#    "Catherine O'Hara",
#    'William Hickey']},
#  {'imdb_id': 'tt0814314',
#   'name': 'Seven Pounds',
#   'num_of_votes': '271334',
#   'gross': '$69.95M',
#   'user_rating': '7.6',
#   'metascore': '36',
#   'genre': ['Drama', 'Romance'],
#   'movie_star': ['Will Smith',
#    'Rosario Dawson',
#    'Woody Harrelson',
#    'Michael Ealy']},
#  {'imdb_id': 'tt1194173',
#   'name': 'The Bourne Legacy',
#   'num_of_votes': '271181',
#   'gross': '$113.20M',
#   'user_rating': '6.7',
#   'metascore': '61',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'movie_star': ['Jeremy Renner',
#    'Rachel Weisz',
#    'Edward Norton',
#    'Scott Glenn']},
#  {'imdb_id': 'tt0878804',
#   'name': 'The Blind Side',
#   'num_of_votes': '271063',
#   'gross': '$255.96M',
#   'user_rating': '7.6',
#   'metascore': '53',
#   'genre': ['Biography', 'Drama', 'Sport'],
#   'movie_star': ['Quinton Aaron', 'Sandra Bullock', 'Tim McGraw', 'Jae Head']},
#  {'imdb_id': 'tt2194499',
#   'name': 'About Time',
#   'num_of_votes': '270656',
#   'gross': '$15.32M',
#   'user_rating': '7.8',
#   'metascore': '55',
#   'genre': ['Comedy', 'Drama', 'Fantasy'],
#   'movie_star': ['Domhnall Gleeson',
#    'Rachel McAdams',
#    'Bill Nighy',
#    'Lydia Wilson']},
#  {'imdb_id': 'tt0071315',
#   'name': 'Chinatown',
#   'num_of_votes': '269968',
#   'gross': '$29.20M',
#   'user_rating': '8.2',
#   'metascore': '92',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'movie_star': ['Jack Nicholson',
#    'Faye Dunaway',
#    'John Huston',
#    'Perry Lopez']},
#  {'imdb_id': 'tt2004420',
#   'name': 'Neighbors',
#   'num_of_votes': '269225',
#   'gross': '$150.16M',
#   'user_rating': '6.3',
#   'metascore': '68',
#   'genre': ['Comedy'],
#   'movie_star': ['Seth Rogen', 'Rose Byrne', 'Zac Efron', 'Lisa Kudrow']},
#  {'imdb_id': 'tt0104431',
#   'name': 'Home Alone 2: Lost in New York',
#   'num_of_votes': '268151',
#   'gross': '$173.59M',
#   'user_rating': '6.7',
#   'metascore': None,
#   'genre': ['Adventure', 'Comedy', 'Crime'],
#   'movie_star': ['Macaulay Culkin',
#    'Joe Pesci',
#    'Daniel Stern',
#    "Catherine O'Hara"]},
#  {'imdb_id': 'tt0092099',
#   'name': 'Top Gun',
#   'num_of_votes': '268005',
#   'gross': '$179.80M',
#   'user_rating': '6.9',
#   'metascore': '50',
#   'genre': ['Action', 'Drama'],
#   'movie_star': ['Tom Cruise', 'Tim Robbins', 'Kelly McGillis', 'Val Kilmer']},
#  {'imdb_id': 'tt0031381',
#   'name': 'Gone with the Wind',
#   'num_of_votes': '267767',
#   'gross': '$198.68M',
#   'user_rating': '8.1',
#   'metascore': '97',
#   'genre': ['Drama', 'History', 'Romance'],
#   'movie_star': ['Clark Gable',
#    'Vivien Leigh',
#    'Thomas Mitchell',
#    "Barbara O'Neil"]},
#  {'imdb_id': 'tt0190590',
#   'name': 'O Brother, Where Art Thou?',
#   'num_of_votes': '267579',
#   'gross': '$45.51M',
#   'user_rating': '7.7',
#   'metascore': '69',
#   'genre': ['Adventure', 'Comedy', 'Crime'],
#   'movie_star': ['George Clooney',
#    'John Turturro',
#    'Tim Blake Nelson',
#    'John Goodman']},
#  {'imdb_id': 'tt0116367',
#   'name': 'From Dusk Till Dawn',
#   'num_of_votes': '267053',
#   'gross': '$25.75M',
#   'user_rating': '7.2',
#   'metascore': '48',
#   'genre': ['Action', 'Crime', 'Horror'],
#   'movie_star': ['Harvey Keitel',
#    'George Clooney',
#    'Juliette Lewis',
#    'Quentin Tarantino']},
#  {'imdb_id': 'tt3682448',
#   'name': 'Bridge of Spies',
#   'num_of_votes': '266746',
#   'gross': '$72.31M',
#   'user_rating': '7.6',
#   'metascore': '81',
#   'genre': ['Drama', 'History', 'Thriller'],
#   'movie_star': ['Tom Hanks', 'Mark Rylance', 'Alan Alda', 'Amy Ryan']},
#  {'imdb_id': 'tt1253863',
#   'name': '300: Rise of an Empire',
#   'num_of_votes': '266239',
#   'gross': '$106.58M',
#   'user_rating': '6.2',
#   'metascore': '48',
#   'genre': ['Action', 'Fantasy'],
#   'movie_star': ['Sullivan Stapleton',
#    'Eva Green',
#    'Lena Headey',
#    'Hans Matheson']},
#  {'imdb_id': 'tt1179933',
#   'name': '10 Cloverfield Lane',
#   'num_of_votes': '265438',
#   'gross': '$71.90M',
#   'user_rating': '7.2',
#   'metascore': '76',
#   'genre': ['Drama', 'Horror', 'Mystery'],
#   'movie_star': ['John Goodman',
#    'Mary Elizabeth Winstead',
#    'John Gallagher Jr.',
#    'Douglas M. Griffin']},
#  {'imdb_id': 'tt0100405',
#   'name': 'Pretty Woman',
#   'num_of_votes': '264714',
#   'gross': '$178.41M',
#   'user_rating': '7.0',
#   'metascore': '51',
#   'genre': ['Comedy', 'Romance'],
#   'movie_star': ['Richard Gere',
#    'Julia Roberts',
#    'Jason Alexander',
#    'Laura San Giacomo']},
#  {'imdb_id': 'tt0117571',
#   'name': 'Scream',
#   'num_of_votes': '264237',
#   'gross': '$103.05M',
#   'user_rating': '7.2',
#   'metascore': '65',
#   'genre': ['Horror', 'Mystery'],
#   'movie_star': ['Neve Campbell',
#    'Courteney Cox',
#    'David Arquette',
#    'Skeet Ulrich']},
#  {'imdb_id': 'tt0884328',
#   'name': 'The Mist',
#   'num_of_votes': '264075',
#   'gross': '$25.59M',
#   'user_rating': '7.1',
#   'metascore': '58',
#   'genre': ['Horror', 'Sci-Fi'],
#   'movie_star': ['Thomas Jane',
#    'Marcia Gay Harden',
#    'Laurie Holden',
#    'Andre Braugher']},
#  {'imdb_id': 'tt0119177',
#   'name': 'Gattaca',
#   'num_of_votes': '263991',
#   'gross': '$12.34M',
#   'user_rating': '7.8',
#   'metascore': '64',
#   'genre': ['Drama', 'Sci-Fi', 'Thriller'],
#   'movie_star': ['Ethan Hawke', 'Uma Thurman', 'Jude Law', 'Gore Vidal']},
#  {'imdb_id': 'tt1152836',
#   'name': 'Public Enemies',
#   'num_of_votes': '263938',
#   'gross': '$97.10M',
#   'user_rating': '7.0',
#   'metascore': '70',
#   'genre': ['Biography', 'Crime', 'Drama'],
#   'movie_star': ['Christian Bale',
#    'Johnny Depp',
#    'Christian Stolte',
#    'Jason Clarke']},
#  {'imdb_id': 'tt0119528',
#   'name': 'Liar Liar',
#   'num_of_votes': '263416',
#   'gross': '$181.41M',
#   'user_rating': '6.9',
#   'metascore': '70',
#   'genre': ['Comedy', 'Fantasy'],
#   'movie_star': ['Jim Carrey',
#    'Maura Tierney',
#    'Amanda Donohoe',
#    'Jennifer Tilly']},
#  {'imdb_id': 'tt0348150',
#   'name': 'Superman Returns',
#   'num_of_votes': '262030',
#   'gross': '$200.08M',
#   'user_rating': '6.0',
#   'metascore': '72',
#   'genre': ['Action', 'Sci-Fi'],
#   'movie_star': ['Brandon Routh',
#    'Kevin Spacey',
#    'Kate Bosworth',
#    'James Marsden']},
#  {'imdb_id': 'tt1735898',
#   'name': 'Snow White and the Huntsman',
#   'num_of_votes': '261269',
#   'gross': '$155.33M',
#   'user_rating': '6.1',
#   'metascore': '57',
#   'genre': ['Action', 'Adventure', 'Drama'],
#   'movie_star': ['Kristen Stewart',
#    'Chris Hemsworth',
#    'Charlize Theron',
#    'Sam Claflin']},
#  {'imdb_id': 'tt0118880',
#   'name': 'Con Air',
#   'num_of_votes': '260334',
#   'gross': '$101.12M',
#   'user_rating': '6.9',
#   'metascore': '52',
#   'genre': ['Action', 'Crime', 'Thriller'],
#   'movie_star': ['Nicolas Cage',
#    'John Cusack',
#    'John Malkovich',
#    'Colm Meaney']},
#  {'imdb_id': 'tt5095030',
#   'name': 'Ant-Man and the Wasp',
#   'num_of_votes': '260231',
#   'gross': '$216.65M',
#   'user_rating': '7.1',
#   'metascore': '70',
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'movie_star': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Michael Peña',
#    'Walton Goggins']},
#  {'imdb_id': 'tt0413267',
#   'name': 'Shrek the Third',
#   'num_of_votes': '260122',
#   'gross': '$320.71M',
#   'user_rating': '6.0',
#   'metascore': '58',
#   'genre': ['Animation', 'Adventure', 'Comedy'],
#   'movie_star': ['Mike Myers',
#    'Cameron Diaz',
#    'Eddie Murphy',
#    'Antonio Banderas']},
#  {'imdb_id': 'tt1981677',
#   'name': 'Pitch Perfect',
#   'num_of_votes': '259898',
#   'gross': '$65.00M',
#   'user_rating': '7.2',
#   'metascore': '66',
#   'genre': ['Comedy', 'Music', 'Romance'],
#   'movie_star': ['Anna Kendrick',
#    'Brittany Snow',
#    'Rebel Wilson',
#    'Anna Camp']}]

# %%
results2 = all_results(1001,api_key)
# Out:
# insterting at 1051
# insterting at 1101
# insterting at 1151
# insterting at 1201
# insterting at 1251
# insterting at 1301
# insterting at 1351
# insterting at 1401
# insterting at 1451
# insterting at 1501

# %%
results3 = all_results(1501,api_key)
# Out:
# insterting at 1551
# insterting at 1601
# insterting at 1651
# insterting at 1701
# insterting at 1751
# insterting at 1801
# insterting at 1851
# insterting at 1901
# insterting at 1951
# insterting at 2001
# insterting at 2051
# insterting at 2101
# insterting at 2151
# insterting at 2201
# insterting at 2251
# insterting at 2301
# insterting at 2351
# insterting at 2401
# insterting at 2451
# insterting at 2501

# %%
results4 = all_results(2501, api_key)
# Out:
# insterting at 2551
# insterting at 2601
# insterting at 2651
# insterting at 2701
# insterting at 2751
# insterting at 2801
# insterting at 2851
# insterting at 2901
# insterting at 2951
# insterting at 3001

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Top 10 rated movies

# %%
top_10 = """SELECT name, user_rating, metascore_rating FROM imdb
ORDER BY user_rating DESC LIMIT 10"""
cursor.execute(top_10)
top_10_df = pd.DataFrame(cursor.fetchall())
top_10_df.columns = [x[0] for x in cursor.description]
top_10_df
# Out:
#                                             name  user_rating  \
# 0                       The Shawshank Redemption          9.3
# 1                                  The Godfather          9.2
# 2                                The Dark Knight          9.0
# 3                         The Godfather: Part II          9.0
# 4                                   Pulp Fiction          8.9
# 5  The Lord of the Rings: The Return of the King          8.9
# 6                               Schindler's List          8.9
# 7                                   12 Angry Men          8.9
# 8                                      Inception          8.8
# 9                                     Fight Club          8.8
#
#    metascore_rating
# 0              80.0
# 1             100.0
# 2              84.0
# 3              90.0
# 4              94.0
# 5              94.0
# 6              94.0
# 7              96.0
# 8              74.0
# 9              66.0

# %%
top_10_df.metascore_rating = top_10_df.metascore_rating.apply(lambda x: x/10)
top_10_df
# Out:
#                                             name  user_rating  \
# 0                       The Shawshank Redemption          9.3
# 1                                  The Godfather          9.2
# 2                                The Dark Knight          9.0
# 3                         The Godfather: Part II          9.0
# 4                                   Pulp Fiction          8.9
# 5  The Lord of the Rings: The Return of the King          8.9
# 6                               Schindler's List          8.9
# 7                                   12 Angry Men          8.9
# 8                                      Inception          8.8
# 9                                     Fight Club          8.8
#
#    metascore_rating
# 0               8.0
# 1              10.0
# 2               8.4
# 3               9.0
# 4               9.4
# 5               9.4
# 6               9.4
# 7               9.6
# 8               7.4
# 9               6.6

# %%
top_10_plot = sns.barplot(x='name', y='user_rating',data=top_10_df)
for index, row in top_10_df.iterrows():
    top_10_plot.text(row.name,row.user_rating, round(row.user_rating,2), color='black', ha="center")

# %%
test_df = pd.melt(top_10_df, id_vars=['name'], value_vars=['user_rating', 'metascore_rating'])

test_top_10 = sns.catplot(x='name', y='value',hue='variable',data=test_df, kind='bar')

# %% [markdown]
# ### Average rating per genre

# %%
genre_rating = """SELECT genre, COUNT(genre),AVG(user_rating) AS avg_rating, AVG(metascore_rating)/10 AS avg_metascore, AVG(vote_average) as tmdb_avg_rating FROM imdb 
                  JOIN genre_1 USING(imdb_id)
                  JOIN tmdb USING(imdb_id)
                  GROUP BY genre
                  HAVING COUNT(genre)>100
                  ORDER BY avg_rating DESC
                    """
cursor.execute(genre_rating)
genre_rating_df = pd.DataFrame(cursor.fetchall())
genre_rating_df.columns = [x[0] for x in cursor.description]
genre_rating_df
# Out:
#         genre  COUNT(genre)  avg_rating  avg_metascore  tmdb_avg_rating
# 0   Biography           202    7.417822       6.967662         7.234158
# 1       Drama          1445    7.155848       6.482913         6.996194
# 2   Animation           180    7.108889       6.807865         6.950000
# 3       Crime           590    6.933220       5.919716         6.747966
# 4    Thriller           575    6.814957       5.837004         6.644870
# 5     Mystery           310    6.804516       5.734122         6.686774
# 6     Romance           417    6.796403       5.839951         6.735492
# 7   Adventure           751    6.752330       5.853125         6.613848
# 8      Family           170    6.720588       6.088125         6.689412
# 9      Sci-Fi           327    6.714373       5.698742         6.549847
# 10     Comedy          1039    6.684023       5.782054         6.565544
# 11    Fantasy           301    6.637542       5.501718         6.544850
# 12     Action           924    6.584524       5.351889         6.428139
# 13     Horror           318    6.440881       5.348693         6.374214

# %%
genre_rating_plot = sns.barplot(x='genre', y='avg_rating',data=genre_rating_df)

# %%
test_genre_df = pd.melt(genre_rating_df, id_vars=['genre'], value_vars=['avg_rating', 'avg_metascore','tmdb_avg_rating'])

# %%
test_genre_df
# Out:
#         genre         variable     value
# 0   Biography       avg_rating  7.417822
# 1       Drama       avg_rating  7.155848
# 2   Animation       avg_rating  7.108889
# 3       Crime       avg_rating  6.933220
# 4    Thriller       avg_rating  6.814957
# 5     Mystery       avg_rating  6.804516
# 6     Romance       avg_rating  6.796403
# 7   Adventure       avg_rating  6.752330
# 8      Family       avg_rating  6.720588
# 9      Sci-Fi       avg_rating  6.714373
# 10     Comedy       avg_rating  6.684023
# 11    Fantasy       avg_rating  6.637542
# 12     Action       avg_rating  6.584524
# 13     Horror       avg_rating  6.440881
# 14  Biography    avg_metascore  6.967662
# 15      Drama    avg_metascore  6.482913
# 16  Animation    avg_metascore  6.807865
# 17      Crime    avg_metascore  5.919716
# 18   Thriller    avg_metascore  5.837004
# 19    Mystery    avg_metascore  5.734122
# 20    Romance    avg_metascore  5.839951
# 21  Adventure    avg_metascore  5.853125
# 22     Family    avg_metascore  6.088125
# 23     Sci-Fi    avg_metascore  5.698742
# 24     Comedy    avg_metascore  5.782054
# 25    Fantasy    avg_metascore  5.501718
# 26     Action    avg_metascore  5.351889
# 27     Horror    avg_metascore  5.348693
# 28  Biography  tmdb_avg_rating  7.234158
# 29      Drama  tmdb_avg_rating  6.996194
# 30  Animation  tmdb_avg_rating  6.950000
# 31      Crime  tmdb_avg_rating  6.747966
# 32   Thriller  tmdb_avg_rating  6.644870
# 33    Mystery  tmdb_avg_rating  6.686774
# 34    Romance  tmdb_avg_rating  6.735492
# 35  Adventure  tmdb_avg_rating  6.613848
# 36     Family  tmdb_avg_rating  6.689412
# 37     Sci-Fi  tmdb_avg_rating  6.549847
# 38     Comedy  tmdb_avg_rating  6.565544
# 39    Fantasy  tmdb_avg_rating  6.544850
# 40     Action  tmdb_avg_rating  6.428139
# 41     Horror  tmdb_avg_rating  6.374214

# %%
# plt.figure(figsize= (16,8))
test_genre_plot = sns.catplot(x='genre', y='value',hue='variable',data=test_genre_df, kind='bar', aspect = 16/8, palette = "husl")
test_genre_plot.set(xlabel = "Genre", ylabel ="Average rating")
loc, labels = plt.xticks()
loc, labels2 = plt.yticks()
test_genre_plot.set_xticklabels(labels,rotation = 45, fontsize = 15);
test_genre_plot.set_yticklabels(labels2, fontsize = 12);
leg_label = ("User", "Critic", "TMDB")
plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Average rating per genre", fontsize=20)
plt.xlabel("Genre", fontsize = 20)
plt.ylabel("Average rating", fontsize = 20)
# Out:
# Text(27.175755208333335, 0.5, 'Average rating')

# %% [markdown]
# ### Gross income by genre

# %%
genre_gross = """SELECT genre, SUBSTRING(gross,2,LENGTH(gross)-2) AS gross FROM imdb
JOIN genre_1 USING(imdb_id) ORDER BY gross DESC;
"""
cursor.execute(genre_gross)
genre_gross_df = pd.DataFrame(cursor.fetchall())
genre_gross_df.columns = [x[0] for x in cursor.description]

# %%
genre_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7879 entries, 0 to 7878
# Data columns (total 2 columns):
# genre    7879 non-null object
# gross    7606 non-null object
# dtypes: object(2)
# memory usage: 123.2+ KB

# %%
genre_gross_df.dropna(inplace = True)

# %%
genre_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7606 entries, 0 to 7605
# Data columns (total 2 columns):
# genre    7606 non-null object
# gross    7606 non-null object
# dtypes: object(2)
# memory usage: 178.3+ KB

# %%
genre_gross_df.gross = genre_gross_df.gross.apply(lambda x: float(x))

# %%
genre_gross_df.groupby('genre').count()
# Out:
#            gross
# genre
# Action       902
# Adventure    738
# Animation    177
# Biography    198
# Comedy      1017
# Crime        554
# Drama       1376
# Family       166
# Fantasy      295
# Film-Noir      8
# History       85
# Horror       299
# Music         66
# Musical       25
# Mystery      295
# Romance      409
# Sci-Fi       316
# Sport         69
# Thriller     549
# War           41
# Western       21

# %% [markdown]
# Plot of income by genre

# %%
plt.figure(figsize = (15,8))
genre_gross_plot = sns.boxplot(x='genre', y='gross',data=genre_gross_df, notch=True, bootstrap=10000,whis = 2)
genre_gross_plot.set_xlabel("Genre", fontsize = 20)
genre_gross_plot.set_ylabel("Gross income [$ in millions]", fontsize = 20)
genre_gross_plot.set_title("Gross income per genre", fontsize = 20)
loc, labels = plt.xticks()
genre_gross_plot.set_xticklabels(labels,rotation = 90, fontsize = 15);
# loc, labels2 = plt.yticks()
# genre_gross_plot.set_yticklabels(labels2, fontsize = 12);
sns.despine()

# %% [markdown]
# Plot of income by genre without outliers

# %%
plt.figure(figsize=(16,8))
genre_gross_plot2 = sns.boxplot(x='genre', y='gross',data=genre_gross_df, showfliers=False)
genre_gross_plot2.set_xlabel("Genre", fontsize = 15)
genre_gross_plot2.set_ylabel("Gross income [$ in millions]", fontsize = 15)
genre_gross_plot2.set_title("Gross income per genre", fontsize = 15)
loc, labels = plt.xticks()
genre_gross_plot2.set_xticklabels(labels,rotation = 45, fontsize = 12);

# %% [markdown]
# ### Popularity of genres based on number of votes

# %%
genre_num_vote = '''SELECT genre, number_of_votes FROM imdb
JOIN genre_1 USING(imdb_id)'''
cursor.execute(genre_num_vote)
genre_num_vote_df = pd.DataFrame(cursor.fetchall())
genre_num_vote_df.columns = [x[0] for x in cursor.description]
genre_num_vote_df
# Out:
#           genre  number_of_votes
# 0         Drama        2135120.0
# 1        Action        2099693.0
# 2         Crime        2099693.0
# 3         Drama        2099693.0
# 4        Action        1872564.0
# 5     Adventure        1872564.0
# 6        Sci-Fi        1872564.0
# 7         Drama        1706903.0
# 8         Crime        1675698.0
# 9         Drama        1675698.0
# 10        Drama        1643165.0
# 11      Romance        1643165.0
# 12       Action        1537647.0
# 13       Sci-Fi        1537647.0
# 14    Adventure        1534117.0
# 15        Drama        1534117.0
# 16      Fantasy        1534117.0
# 17    Adventure        1518488.0
# 18        Drama        1518488.0
# 19      Fantasy        1518488.0
# 20        Crime        1465935.0
# 21        Drama        1465935.0
# 22       Action        1406918.0
# 23     Thriller        1406918.0
# 24    Adventure        1373472.0
# 25        Drama        1373472.0
# 26      Fantasy        1373472.0
# 27    Adventure        1329051.0
# 28        Drama        1329051.0
# 29       Sci-Fi        1329051.0
# ...         ...              ...
# 7849     Comedy          49074.0
# 7850      Drama          49074.0
# 7851      Music          49074.0
# 7852     Action          49051.0
# 7853      Drama          49051.0
# 7854    Romance          49051.0
# 7855     Comedy          49025.0
# 7856      Drama          49025.0
# 7857     Family          49025.0
# 7858  Biography          48975.0
# 7859      Drama          48975.0
# 7860      Music          48975.0
# 7861     Comedy          48930.0
# 7862     Horror          48930.0
# 7863      Drama          48871.0
# 7864        War          48871.0
# 7865     Comedy          48863.0
# 7866      Crime          48863.0
# 7867      Drama          48863.0
# 7868  Animation          48853.0
# 7869  Adventure          48853.0
# 7870     Comedy          48853.0
# 7871      Drama          48818.0
# 7872   Thriller          48818.0
# 7873     Comedy          48791.0
# 7874      Drama          48791.0
# 7875    Romance          48791.0
# 7876      Crime          48788.0
# 7877   Thriller          48788.0
# 7878     Horror          48786.0
#
# [7879 rows x 2 columns]

# %%
genre_num_vote_plot = sns.catplot(x='genre',y='number_of_votes',data=genre_num_vote_df,jitter='0.25', aspect = 16/8)
# test_genre_plot.set(xlabel = "Genre", ylabel ="Number of votes")
loc, labels = plt.xticks()
loc, labels2 = plt.yticks()
genre_num_vote_plot.set_xticklabels(labels,rotation = 90, fontsize = 15);
genre_num_vote_plot.set_yticklabels(labels2, fontsize = 12);
# leg_label = ("User", "Critic", "TMDB")
# plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Popularity of genres based on number of votes", fontsize=20)
plt.xlabel("Genre", fontsize = 20)
plt.ylabel("Number of votes", fontsize = 20);

# %% [markdown]
# ### Most popular month for movie release

# %%
release_date_num_of_vote = """SELECT MONTH(release_date) AS release_month,COUNT(imdb_id) AS number_of_movies, sum(number_of_votes) AS total_num_votes, MIN(release_date), MAX(release_date)
FROM imdb JOIN tmdb USING(imdb_id)
GROUP BY release_month"""
cursor.execute(release_date_num_of_vote)
release_date_num_of_vote_df = pd.DataFrame(cursor.fetchall())
release_date_num_of_vote_df.columns = [x[0] for x in cursor.description]
release_date_num_of_vote_df
# Out:
#     release_month  number_of_movies  total_num_votes MIN(release_date)  \
# 0               1               141       16559961.0        1940-01-18
# 1               2               192       31823328.0        1921-02-06
# 2               3               231       40140717.0        1940-03-15
# 3               4               182       31916798.0        1930-04-29
# 4               5               237       54334862.0        1954-05-29
# 5               6               310       60794828.0        1925-06-25
# 6               7               265       54035772.0        1951-07-03
# 7               8               241       35805451.0        1939-08-15
# 8               9               314       54105529.0        1944-09-23
# 9              10               273       49636477.0        1939-10-19
# 10             11               245       48391762.0        1931-11-21
# 11             12               369       72734403.0        1926-12-31
#
#    MAX(release_date)
# 0         2019-01-31
# 1         2018-02-28
# 2         2019-03-23
# 3         2019-04-24
# 4         2019-05-29
# 5         2019-06-28
# 6         2019-07-25
# 7         2019-08-01
# 8         2019-09-04
# 9         2018-10-24
# 10        2018-11-27
# 11        2018-12-28

# %%
plt.figure(figsize=(16,8))
release_date_num_of_vote_plot = sns.barplot(x='release_month', y = 'number_of_movies', data = release_date_num_of_vote_df)
loc, labels = plt.xticks()
# loc, labels2 = plt.yticks()
release_date_num_of_vote_plot.set_xticklabels(labels, fontsize = 20);
# release_date_num_of_vote_plot.set_yticklabels(labels2, fontsize = 12);
# leg_label = ("User", "Critic", "TMDB")
# plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Most popular month for movie release in dataset", fontsize=20)
plt.xlabel("Month", fontsize = 20)
plt.ylabel("Number of movies released", fontsize = 20);

for index, row in release_date_num_of_vote_df.iterrows():
    release_date_num_of_vote_plot.text(row.name,row.number_of_movies, int(row.number_of_movies), color='black', ha="center", fontsize = 15)
    sns.despine()

# %% [markdown]
# ### Average movie rating per month

# %%
release_date_avg_rating = """SELECT MONTH(release_date) AS release_month, COUNT(imdb_id), AVG(user_rating) AS user_rating
FROM imdb JOIN tmdb USING(imdb_id)
GROUP BY release_month
"""
cursor.execute(release_date_avg_rating)
release_date_avg_rating_df = pd.DataFrame(cursor.fetchall())
release_date_avg_rating_df.columns = [x[0] for x in cursor.description]

# %%
release_date_avg_rating_df
# Out:
#     release_month  COUNT(imdb_id)  user_rating
# 0               1             141     6.585106
# 1               2             192     6.711458
# 2               3             231     6.717749
# 3               4             182     6.784066
# 4               5             237     6.816034
# 5               6             310     6.732258
# 6               7             265     6.733208
# 7               8             241     6.755602
# 8               9             314     7.019427
# 9              10             273     7.010989
# 10             11             245     6.986939
# 11             12             369     7.088618

# %%
plt.figure(figsize=(16,4))
release_date_rating_plot = sns.barplot(x='release_month', y = 'user_rating', data = release_date_avg_rating_df)

loc, labels = plt.xticks()
# loc, labels2 = plt.yticks()
release_date_rating_plot.set_xticklabels(labels, fontsize = 20);
# release_date_num_of_vote_plot.set_yticklabels(labels2, fontsize = 12);
# leg_label = ("User", "Critic", "TMDB")
# plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Average movie rating per month", fontsize=20)
plt.xlabel("Month", fontsize = 20)
plt.ylabel("Average user rating", fontsize = 20);
plt.ylim(6,7.5)
for index, row in release_date_avg_rating_df.iterrows():
    release_date_rating_plot.text(row.name,row.user_rating, round(row.user_rating,2), color='black', ha="center", fontsize = 15)
sns.despine()

# %% [markdown]
# ### Time range of distribution of datapoints

# %%
release_year_avg_rating = """SELECT YEAR(release_date) AS release_year, COUNT(imdb_id) as count
FROM imdb JOIN tmdb USING(imdb_id)
GROUP BY release_year
"""
cursor.execute(release_year_avg_rating)
release_year_avg_rating_df = pd.DataFrame(cursor.fetchall())
release_year_avg_rating_df.columns = [x[0] for x in cursor.description]

# %%
release_year_avg_rating_df
# Out:
#     release_year  count
# 0           1921      1
# 1           1925      1
# 2           1926      1
# 3           1930      1
# 4           1931      2
# 5           1933      2
# 6           1934      1
# 7           1936      1
# 8           1937      1
# 9           1938      1
# 10          1939      3
# 11          1940      7
# 12          1941      3
# 13          1942      2
# 14          1943      1
# 15          1944      2
# 16          1946      4
# 17          1948      3
# 18          1949      1
# 19          1950      4
# 20          1951      5
# 21          1952      2
# 22          1953      3
# 23          1954      4
# 24          1955      5
# 25          1956      4
# 26          1957      4
# 27          1958      2
# 28          1959      7
# 29          1960      6
# ..           ...    ...
# 59          1990     30
# 60          1991     27
# 61          1992     35
# 62          1993     37
# 63          1994     39
# 64          1995     52
# 65          1996     48
# 66          1997     59
# 67          1998     72
# 68          1999     77
# 69          2000     71
# 70          2001     87
# 71          2002     83
# 72          2003     91
# 73          2004     95
# 74          2005    112
# 75          2006    114
# 76          2007    125
# 77          2008    122
# 78          2009    131
# 79          2010    124
# 80          2011    146
# 81          2012    119
# 82          2013    142
# 83          2014    123
# 84          2015    108
# 85          2016    121
# 86          2017     92
# 87          2018     71
# 88          2019     28
#
# [89 rows x 2 columns]

# %% [markdown]
# Converting years to decades

# %%
decade_dict = {}
for index,year in enumerate(release_year_avg_rating_df["release_year"]):
    decade = int(year)//10
    if decade in decade_dict:
        decade_dict[decade] += release_year_avg_rating_df["count"][index]
    else:
        decade_dict[decade] = release_year_avg_rating_df["count"][index]
    decade_dict["total"] = sum(release_year_avg_rating_df["count"])
decade_dict
# Out:
# {192: 3,
#  'total': 3000,
#  193: 12,
#  194: 23,
#  195: 40,
#  196: 53,
#  197: 76,
#  198: 212,
#  199: 476,
#  200: 1031,
#  201: 1074}

# %%
total_dict = {'total': }

# %%
table_year = pd.DataFrame.from_dict(decade_dict,orient='index')
table_year.rename(index={192:'1920s',193:'1930s',194:'1940s',195:'1950s', 196:'1960s', 197:'1970s', 198:'1980s',199:'1990s',200:'2000s',201:'2010s'}, inplace=True)
row_names = ['1920s','1930s','1940s','1950s','1960s','1970s','1980s','1990s','2000s','2010s']
table_year.reset_index().sort_values(by=['index']).rename(columns ={'index' : "Decades", 0:"Count"})
# Out:
#    Decades  Count
# 0    1920s      3
# 2    1930s     12
# 3    1940s     23
# 4    1950s     40
# 5    1960s     53
# 6    1970s     76
# 7    1980s    212
# 8    1990s    476
# 9    2000s   1031
# 10   2010s   1074
# 1    total   3000

# %%
# !pip install plotly
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
hist_decades = decade_dict

init_notebook_mode(connected=True)
iplot([{'type':'bar','x' : ['1920s','1930s','1940s','1950s','1960s','1970s','1980s','1990s','2000s','2010s'],'y': list(hist_decades.values())}])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="5ba24b09-8128-4d33-b30f-a27ea9e6c084" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ba24b09-8128-4d33-b30f-a27ea9e6c084")) {
#                     Plotly.newPlot(
#                         '5ba24b09-8128-4d33-b30f-a27ea9e6c084',
#                         [{"type": "bar", "x": ["1920s", "1930s", "1940s", "1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s"], "y": [3, 12, 23, 40, 53, 76, 212, 476, 1031, 1074]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...
#                         {"responsive": true}

# %%
table_year.reset_index().sort_values(by=['index']).transpose().rename(index ={'index' : "Decades", 0:"Count"})
# Out:
#             0      2      3      4      5      6      7      8      9      10  \
# Decades  1920s  1930s  1940s  1950s  1960s  1970s  1980s  1990s  2000s  2010s
# Count        3     12     23     40     53     76    212    476   1031   1074
#
#             1
# Decades  total
# Count     3000

# %% [markdown]
# ### User rating per genre

# %%
genre_rating_scat = """SELECT genre,user_rating, (metascore_rating)/10 AS metascore, vote_average as tmdb_rating FROM imdb 
                  JOIN genre_1 USING(imdb_id)
                  JOIN tmdb USING(imdb_id)
                  ORDER BY user_rating DESC
                    """
cursor.execute(genre_rating_scat)
genre_rating_scat_df = pd.DataFrame(cursor.fetchall())
genre_rating_scat_df.columns = [x[0] for x in cursor.description]
genre_rating_scat_df

# %%
genre_rating_scat_plot = sns.catplot(x='genre',y='user_rating',data=genre_rating_scat_df,jitter='0.25', aspect = 16/8)
# test_genre_plot.set(xlabel = "Genre", ylabel ="Number of votes")
loc, labels = plt.xticks()
loc, labels2 = plt.yticks()
genre_rating_scat_plot.set_xticklabels(labels,rotation = 45, fontsize = 12);
genre_rating_scat_plot.set_yticklabels(labels2, fontsize = 12);
# leg_label = ("User", "Critic", "TMDB")
# plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Popularity of genres based on number of votes", fontsize=15)
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("User rating", fontsize = 15);

# %%
genre_rating_scat_df_melt = pd.melt(genre_rating_scat_df, id_vars = ['genre'], value_vars = ['user_rating','metascore'])
genre_rating_scat_df_melt
# Out:
#            genre     variable  value
# 0          Drama  user_rating    9.3
# 1          Crime  user_rating    9.2
# 2          Drama  user_rating    9.2
# 3         Action  user_rating    9.0
# 4          Crime  user_rating    9.0
# 5          Drama  user_rating    9.0
# 6          Crime  user_rating    9.0
# 7          Drama  user_rating    9.0
# 8          Crime  user_rating    8.9
# 9          Drama  user_rating    8.9
# 10     Adventure  user_rating    8.9
# 11         Drama  user_rating    8.9
# 12       Fantasy  user_rating    8.9
# 13     Biography  user_rating    8.9
# 14         Drama  user_rating    8.9
# 15       History  user_rating    8.9
# 16         Drama  user_rating    8.9
# 17        Action  user_rating    8.8
# 18     Adventure  user_rating    8.8
# 19        Sci-Fi  user_rating    8.8
# 20         Drama  user_rating    8.8
# 21         Drama  user_rating    8.8
# 22       Romance  user_rating    8.8
# 23     Adventure  user_rating    8.8
# 24         Drama  user_rating    8.8
# 25       Fantasy  user_rating    8.8
# 26       Western  user_rating    8.8
# 27        Action  user_rating    8.7
# 28        Sci-Fi  user_rating    8.7
# 29     Adventure  user_rating    8.7
# ...          ...          ...    ...
# 15728     Comedy    metascore    NaN
# 15729     Action    metascore    2.8
# 15730     Sci-Fi    metascore    2.8
# 15731      Drama    metascore    0.9
# 15732     Horror    metascore    3.6
# 15733    Mystery    metascore    3.6
# 15734   Thriller    metascore    3.6
# 15735     Comedy    metascore    1.1
# 15736     Action    metascore    2.7
# 15737      Crime    metascore    2.7
# 15738    Fantasy    metascore    2.7
# 15739     Comedy    metascore    2.3
# 15740  Animation    metascore    1.2
# 15741  Adventure    metascore    1.2
# 15742     Comedy    metascore    1.2
# 15743     Comedy    metascore    0.9
# 15744     Comedy    metascore    1.1
# 15745    Romance    metascore    1.1
# 15746     Action    metascore    0.9
# 15747  Adventure    metascore    0.9
# 15748     Sci-Fi    metascore    0.9
# 15749     Action    metascore    4.5
# 15750  Adventure    metascore    4.5
# 15751    Fantasy    metascore    4.5
# 15752  Adventure    metascore    1.7
# 15753     Comedy    metascore    1.7
# 15754     Comedy    metascore    2.0
# 15755     Family    metascore    2.0
# 15756    Fantasy    metascore    2.0
# 15757     Comedy    metascore    1.5
#
# [15758 rows x 3 columns]

# %% [markdown]
# ### Rating distribution per genre

# %%
genre_rating_scat = """SELECT genre,user_rating, (metascore_rating)/10 AS metascore, vote_average as tmdb_rating FROM imdb 
                  JOIN genre_1 USING(imdb_id)
                  JOIN tmdb USING(imdb_id)
                  ORDER BY user_rating DESC
                    """
cursor.execute(genre_rating_scat)
genre_rating_scat_df = pd.DataFrame(cursor.fetchall())
genre_rating_scat_df.columns = [x[0] for x in cursor.description]
genre_rating_scat_df
# Out:
#           genre  user_rating  metascore  tmdb_rating
# 0         Drama          9.3        8.0          8.7
# 1         Crime          9.2       10.0          8.6
# 2         Drama          9.2       10.0          8.6
# 3        Action          9.0        8.4          8.4
# 4         Crime          9.0        8.4          8.4
# 5         Drama          9.0        8.4          8.4
# 6         Crime          9.0        9.0          8.5
# 7         Drama          9.0        9.0          8.5
# 8         Crime          8.9        9.4          8.4
# 9         Drama          8.9        9.4          8.4
# 10    Adventure          8.9        9.4          8.4
# 11        Drama          8.9        9.4          8.4
# 12      Fantasy          8.9        9.4          8.4
# 13    Biography          8.9        9.4          8.6
# 14        Drama          8.9        9.4          8.6
# 15      History          8.9        9.4          8.6
# 16        Drama          8.9        9.6          8.4
# 17       Action          8.8        7.4          8.3
# 18    Adventure          8.8        7.4          8.3
# 19       Sci-Fi          8.8        7.4          8.3
# 20        Drama          8.8        6.6          8.4
# 21        Drama          8.8        8.2          8.4
# 22      Romance          8.8        8.2          8.4
# 23    Adventure          8.8        9.2          8.3
# 24        Drama          8.8        9.2          8.3
# 25      Fantasy          8.8        9.2          8.3
# 26      Western          8.8        9.0          8.4
# 27       Action          8.7        7.3          8.1
# 28       Sci-Fi          8.7        7.3          8.1
# 29    Adventure          8.7        8.7          8.3
# ...         ...          ...        ...          ...
# 7849     Comedy          3.9        NaN          4.2
# 7850     Action          3.7        2.8          4.2
# 7851     Sci-Fi          3.7        2.8          4.2
# 7852      Drama          3.7        0.9          4.2
# 7853     Horror          3.7        3.6          4.2
# 7854    Mystery          3.7        3.6          4.2
# 7855   Thriller          3.7        3.6          4.2
# 7856     Comedy          3.5        1.1          4.7
# 7857     Action          3.3        2.7          4.4
# 7858      Crime          3.3        2.7          4.4
# 7859    Fantasy          3.3        2.7          4.4
# 7860     Comedy          3.3        2.3          4.1
# 7861  Animation          3.2        1.2          5.4
# 7862  Adventure          3.2        1.2          5.4
# 7863     Comedy          3.2        1.2          5.4
# 7864     Comedy          2.8        0.9          3.7
# 7865     Comedy          2.8        1.1          3.8
# 7866    Romance          2.8        1.1          3.8
# 7867     Action          2.5        0.9          3.0
# 7868  Adventure          2.5        0.9          3.0
# 7869     Sci-Fi          2.5        0.9          3.0
# 7870     Action          2.5        4.5          2.5
# 7871  Adventure          2.5        4.5          2.5
# 7872    Fantasy          2.5        4.5          2.5
# 7873  Adventure          2.4        1.7          3.4
# 7874     Comedy          2.4        1.7          3.4
# 7875     Comedy          2.2        2.0          3.9
# 7876     Family          2.2        2.0          3.9
# 7877    Fantasy          2.2        2.0          3.9
# 7878     Comedy          1.9        1.5          3.1
#
# [7879 rows x 4 columns]

# %%
g = sns.FacetGrid(genre_rating_scat_df, col="genre", margin_titles=True,palette='Set1')
g.map(plt.scatter, "user_rating",'metascore', alpha=.7)
g.add_legend();

# %%
g = sns.PairGrid(genre_rating_scat_df, hue="genre")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend();

# %% [markdown]
# ### Average gross income per month

# %%
genre_gross = """SELECT MONTH(release_date) AS month, AVG(SUBSTRING(gross,2,LENGTH(gross)-2)) as gross FROM imdb 
                  JOIN genre_1 USING(imdb_id)
                  JOIN tmdb USING(imdb_id)
                  GROUP BY month
                    """
cursor.execute(genre_gross)
genre_gross_df = pd.DataFrame(cursor.fetchall())
genre_gross_df.columns = [x[0] for x in cursor.description]
genre_gross_df
# Out:
#     month       gross
# 0       1   41.668017
# 1       2   61.018525
# 2       3   72.926242
# 3       4   79.018556
# 4       5  110.255237
# 5       6  112.324551
# 6       7   87.587254
# 7       8   57.294219
# 8       9   38.713337
# 9      10   58.300608
# 10     11   92.482979
# 11     12   85.564249

# %%
plt.figure(figsize=(16,8))
genre_gross_plot = sns.barplot(x='month', y = 'gross', data = genre_gross_df)
loc, labels = plt.xticks()
# loc, labels2 = plt.yticks()
genre_gross_plot.set_xticklabels(labels, fontsize = 20);
# release_date_num_of_vote_plot.set_yticklabels(labels2, fontsize = 12);
# leg_label = ("User", "Critic", "TMDB")
# plt.legend(fontsize='x-large', title_fontsize='40', loc = 4)
plt.title("Average gross income per month", fontsize=20)
plt.xlabel("Month", fontsize = 20)
plt.ylabel("Gross ($ in millions)", fontsize = 20);

for index, row in genre_gross_df.iterrows():
    genre_gross_plot.text(row.name,row.gross, round(row.gross,2), color='black', ha="center", fontsize = 15)
    sns.despine()

# %% [markdown]
# Closing all connections

# %%
cursor.close()
cnx.close()
